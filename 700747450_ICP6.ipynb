# %% [markdown]
# <a href="https://colab.research.google.com/github/rmounica/assign6/blob/main/700747450_ICP6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')

path_to_csv = '/content/gdrive/My Drive/breastcancer.csv'

import keras
import pandas as pd
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Activation
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split

# loading dataset
cancer_data = load_breast_cancer()
X_train, X_test, Y_train, Y_test = train_test_split(cancer_data.data, cancer_data.target,
                                                    test_size=0.25, random_state=87)
np.random.seed(155)
my_nn_model = Sequential() # creating the model
my_nn_model.add(Dense(20, input_dim=30, activation='relu')) # hidden layer 1
my_nn_model.add(Dense(32, activation='relu'))
my_nn_model.add(Dense(1, activation='sigmoid')) # output layer
my_nn_model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['acc'])
my_nn_fitted = my_nn_model.fit(X_train, Y_train, epochs=100,
                         initial_epoch=0)
print(my_nn_model.summary())
print(my_nn_model.evaluate(X_test, Y_test))
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# Epoch 1/100
# 14/14 [==============================] - 1s 2ms/step - loss: 12.1129 - acc: 0.4554
# Epoch 2/100
# 14/14 [==============================] - 0s 2ms/step - loss: 4.7353 - acc: 0.3615
# Epoch 3/100
# 14/14 [==============================] - 0s 2ms/step - loss: 2.1462 - acc: 0.4953
# Epoch 4/100
# 14/14 [==============================] - 0s 2ms/step - loss: 1.1918 - acc: 0.6690
# Epoch 5/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.8686 - acc: 0.7793
# Epoch 6/100
# 14/14 [==============================] - 0s 19ms/step - loss: 0.6808 - acc: 0.7817
# Epoch 7/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.5610 - acc: 0.8333
# Epoch 8/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.5411 - acc: 0.8192
# Epoch 9/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.4836 - acc: 0.8779
# Epoch 10/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3542 - acc: 0.8826
# Epoch 11/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2610 - acc: 0.9061
# Epoch 12/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2777 - acc: 0.9014
# Epoch 13/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2769 - acc: 0.9061
# Epoch 14/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2641 - acc: 0.9131
# Epoch 15/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2275 - acc: 0.9202
# Epoch 16/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2291 - acc: 0.9131
# Epoch 17/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2285 - acc: 0.9272
# Epoch 18/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2156 - acc: 0.9131
# Epoch 19/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2163 - acc: 0.9225
# Epoch 20/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1913 - acc: 0.9319
# Epoch 21/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1894 - acc: 0.9437
# Epoch 22/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2226 - acc: 0.9249
# Epoch 23/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1973 - acc: 0.9296
# Epoch 24/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1909 - acc: 0.9296
# Epoch 25/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2305 - acc: 0.9272
# Epoch 26/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2053 - acc: 0.9272
# Epoch 27/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2357 - acc: 0.9296
# Epoch 28/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2017 - acc: 0.9296
# Epoch 29/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2461 - acc: 0.9202
# Epoch 30/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2343 - acc: 0.9202
# Epoch 31/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2084 - acc: 0.9249
# Epoch 32/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1908 - acc: 0.9319
# Epoch 33/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2472 - acc: 0.9225
# Epoch 34/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1797 - acc: 0.9249
# Epoch 35/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2130 - acc: 0.9225
# Epoch 36/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1867 - acc: 0.9296
# Epoch 37/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1934 - acc: 0.9296
# Epoch 38/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1977 - acc: 0.9296
# Epoch 39/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1702 - acc: 0.9319
# Epoch 40/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1753 - acc: 0.9343
# Epoch 41/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1804 - acc: 0.9249
# Epoch 42/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2799 - acc: 0.9131
# Epoch 43/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2745 - acc: 0.9155
# Epoch 44/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2745 - acc: 0.8897
# Epoch 45/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2095 - acc: 0.9178
# Epoch 46/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2403 - acc: 0.9249
# Epoch 47/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1819 - acc: 0.9413
# Epoch 48/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1963 - acc: 0.9319
# Epoch 49/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1777 - acc: 0.9413
# Epoch 50/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1759 - acc: 0.9343
# Epoch 51/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1611 - acc: 0.9343
# Epoch 52/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1620 - acc: 0.9366
# Epoch 53/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1960 - acc: 0.9155
# Epoch 54/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2200 - acc: 0.9178
# Epoch 55/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1822 - acc: 0.9343
# Epoch 56/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2012 - acc: 0.9225
# Epoch 57/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1920 - acc: 0.9343
# Epoch 58/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1960 - acc: 0.9249
# Epoch 59/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1549 - acc: 0.9366
# Epoch 60/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1977 - acc: 0.9178
# Epoch 61/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1838 - acc: 0.9366
# Epoch 62/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1813 - acc: 0.9390
# Epoch 63/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2225 - acc: 0.9343
# Epoch 64/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1553 - acc: 0.9296
# Epoch 65/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1575 - acc: 0.9390
# Epoch 66/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1613 - acc: 0.9390
# Epoch 67/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2378 - acc: 0.8991
# Epoch 68/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1600 - acc: 0.9343
# Epoch 69/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2067 - acc: 0.9178
# Epoch 70/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2076 - acc: 0.9249
# Epoch 71/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1564 - acc: 0.9390
# Epoch 72/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1819 - acc: 0.9296
# Epoch 73/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1749 - acc: 0.9319
# Epoch 74/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1948 - acc: 0.9178
# Epoch 75/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2452 - acc: 0.9319
# Epoch 76/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2572 - acc: 0.9131
# Epoch 77/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2056 - acc: 0.9225
# Epoch 78/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2970 - acc: 0.9155
# Epoch 79/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1902 - acc: 0.9390
# Epoch 80/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1779 - acc: 0.9272
# Epoch 81/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1445 - acc: 0.9319
# Epoch 82/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1809 - acc: 0.9343
# Epoch 83/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1453 - acc: 0.9343
# Epoch 84/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1463 - acc: 0.9437
# Epoch 85/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1731 - acc: 0.9319
# Epoch 86/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1949 - acc: 0.9366
# Epoch 87/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1596 - acc: 0.9366
# Epoch 88/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1568 - acc: 0.9437
# Epoch 89/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1412 - acc: 0.9390
# Epoch 90/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1929 - acc: 0.9366
# Epoch 91/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2233 - acc: 0.9202
# Epoch 92/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1859 - acc: 0.9178
# Epoch 93/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1737 - acc: 0.9249
# Epoch 94/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1528 - acc: 0.9413
# Epoch 95/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1409 - acc: 0.9484
# Epoch 96/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1815 - acc: 0.9272
# Epoch 97/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1358 - acc: 0.9413
# Epoch 98/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1693 - acc: 0.9319
# Epoch 99/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1500 - acc: 0.9366
# Epoch 100/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1598 - acc: 0.9413
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_2 (Dense)             (None, 20)                620
#
#  dense_3 (Dense)             (None, 32)                672
#
#  dense_4 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 1325 (5.18 KB)
# Trainable params: 1325 (5.18 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# 5/5 [==============================] - 0s 6ms/step - loss: 0.1772 - acc: 0.9441
# [0.17724427580833435, 0.9440559148788452]

# %%
# Normalize the data before feeding the data to the model and check how the normalization change your accuracy
from google.colab import drive
drive.mount('/content/gdrive')

path_to_csv = '/content/gdrive/My Drive/breastcancer.csv'

from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

import keras
import pandas as pd
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Activation
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split

# loading dataset
cancer_data = load_breast_cancer()
X_train, X_test, Y_train, Y_test = train_test_split(cancer_data.data, cancer_data.target,
                                                    test_size=0.25, random_state=87)
np.random.seed(155)
my_nn_model = Sequential() # creating model
my_nn_model.add(Dense(20, input_dim=30, activation='relu')) # hidden layer 1
my_nn_model.add(Dense(1, activation='sigmoid')) # output layer
my_nn_model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['acc'])
my_nn_fitted = my_nn_model.fit(X_train, Y_train, epochs=100,
                         initial_epoch=0)
print(my_nn_model.summary())
print(my_nn_model.evaluate(X_test, Y_test))
# Out:
# Mounted at /content/gdrive
# Epoch 1/100
# 14/14 [==============================] - 1s 3ms/step - loss: 63.8194 - acc: 0.3803
# Epoch 2/100
# 14/14 [==============================] - 0s 2ms/step - loss: 41.8421 - acc: 0.3803
# Epoch 3/100
# 14/14 [==============================] - 0s 2ms/step - loss: 21.1435 - acc: 0.3779
# Epoch 4/100
# 14/14 [==============================] - 0s 2ms/step - loss: 7.2538 - acc: 0.3075
# Epoch 5/100
# 14/14 [==============================] - 0s 2ms/step - loss: 2.3582 - acc: 0.5164
# Epoch 6/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.6780 - acc: 0.8545
# Epoch 7/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.5069 - acc: 0.8615
# Epoch 8/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.4935 - acc: 0.8850
# Epoch 9/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.4341 - acc: 0.8826
# Epoch 10/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.4334 - acc: 0.8779
# Epoch 11/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.4212 - acc: 0.8967
# Epoch 12/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.4219 - acc: 0.8779
# Epoch 13/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3756 - acc: 0.8944
# Epoch 14/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.4066 - acc: 0.8944
# Epoch 15/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3665 - acc: 0.8944
# Epoch 16/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3406 - acc: 0.9061
# Epoch 17/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3357 - acc: 0.9014
# Epoch 18/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3240 - acc: 0.9061
# Epoch 19/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3214 - acc: 0.9178
# Epoch 20/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3400 - acc: 0.9085
# Epoch 21/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2939 - acc: 0.9178
# Epoch 22/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3479 - acc: 0.8991
# Epoch 23/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3245 - acc: 0.9085
# Epoch 24/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2902 - acc: 0.9225
# Epoch 25/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2896 - acc: 0.9202
# Epoch 26/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2553 - acc: 0.9202
# Epoch 27/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2752 - acc: 0.9131
# Epoch 28/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2503 - acc: 0.9343
# Epoch 29/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2414 - acc: 0.9225
# Epoch 30/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2394 - acc: 0.9249
# Epoch 31/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2589 - acc: 0.9155
# Epoch 32/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2322 - acc: 0.9225
# Epoch 33/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2152 - acc: 0.9319
# Epoch 34/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2201 - acc: 0.9319
# Epoch 35/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2304 - acc: 0.9225
# Epoch 36/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2408 - acc: 0.9178
# Epoch 37/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2094 - acc: 0.9319
# Epoch 38/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2005 - acc: 0.9343
# Epoch 39/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2267 - acc: 0.9272
# Epoch 40/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2410 - acc: 0.9202
# Epoch 41/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2118 - acc: 0.9249
# Epoch 42/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1856 - acc: 0.9413
# Epoch 43/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1801 - acc: 0.9390
# Epoch 44/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1712 - acc: 0.9366
# Epoch 45/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1694 - acc: 0.9366
# Epoch 46/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2044 - acc: 0.9366
# Epoch 47/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2584 - acc: 0.9178
# Epoch 48/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1850 - acc: 0.9249
# Epoch 49/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1734 - acc: 0.9343
# Epoch 50/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2174 - acc: 0.9155
# Epoch 51/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1867 - acc: 0.9296
# Epoch 52/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1547 - acc: 0.9460
# Epoch 53/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1615 - acc: 0.9390
# Epoch 54/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1699 - acc: 0.9319
# Epoch 55/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1674 - acc: 0.9437
# Epoch 56/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1730 - acc: 0.9296
# Epoch 57/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2075 - acc: 0.9343
# Epoch 58/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1475 - acc: 0.9366
# Epoch 59/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1541 - acc: 0.9296
# Epoch 60/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1504 - acc: 0.9390
# Epoch 61/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1466 - acc: 0.9413
# Epoch 62/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1584 - acc: 0.9343
# Epoch 63/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2234 - acc: 0.9249
# Epoch 64/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1850 - acc: 0.9249
# Epoch 65/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1910 - acc: 0.9272
# Epoch 66/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1636 - acc: 0.9319
# Epoch 67/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1489 - acc: 0.9319
# Epoch 68/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1335 - acc: 0.9460
# Epoch 69/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1892 - acc: 0.9296
# Epoch 70/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1423 - acc: 0.9413
# Epoch 71/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1332 - acc: 0.9413
# Epoch 72/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1402 - acc: 0.9554
# Epoch 73/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1387 - acc: 0.9390
# Epoch 74/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1523 - acc: 0.9460
# Epoch 75/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1487 - acc: 0.9366
# Epoch 76/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1690 - acc: 0.9366
# Epoch 77/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1816 - acc: 0.9319
# Epoch 78/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1578 - acc: 0.9296
# Epoch 79/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1390 - acc: 0.9343
# Epoch 80/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1491 - acc: 0.9460
# Epoch 81/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1432 - acc: 0.9507
# Epoch 82/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1534 - acc: 0.9437
# Epoch 83/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1343 - acc: 0.9390
# Epoch 84/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1346 - acc: 0.9413
# Epoch 85/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1459 - acc: 0.9296
# Epoch 86/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1440 - acc: 0.9554
# Epoch 87/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1685 - acc: 0.9390
# Epoch 88/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1538 - acc: 0.9343
# Epoch 89/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1332 - acc: 0.9437
# Epoch 90/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1521 - acc: 0.9460
# Epoch 91/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1558 - acc: 0.9507
# Epoch 92/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1732 - acc: 0.9296
# Epoch 93/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1732 - acc: 0.9343
# Epoch 94/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2000 - acc: 0.9225
# Epoch 95/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1439 - acc: 0.9484
# Epoch 96/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1214 - acc: 0.9531
# Epoch 97/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1442 - acc: 0.9366
# Epoch 98/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1628 - acc: 0.9366
# Epoch 99/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1529 - acc: 0.9272
# Epoch 100/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1250 - acc: 0.9460
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 20)                620
#
#  dense_1 (Dense)             (None, 1)                 21
#
# =================================================================
# Total params: 641 (2.50 KB)
# Trainable params: 641 (2.50 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# 5/5 [==============================] - 0s 3ms/step - loss: 0.2272 - acc: 0.9161
# [0.22720931470394135, 0.9160839319229126]

# %%
# Plot the loss and accuracy for both training data and validation data using the history object in the source code
import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout
import matplotlib.pyplot as plt

# load mnist dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# normalize pixel values to range [0, 1]
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

# converting class labels to binary class matrices
num_classes = 10
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# creating a simple neural network model
model = Sequential()
model.add(Dense(512, activation='relu', input_shape=(784,)))
model.add(Dropout(0.2))
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation='softmax'))

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# training the model and record the training history
history = model.fit(x_train.reshape(-1, 784), y_train, validation_data=(x_test.reshape(-1, 784), y_test),
                    epochs=20, batch_size=128)

# to plot the training and validation accuracy and loss curves
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='lower right')

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper right')

plt.show()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 1s 0us/step
# Epoch 1/20
# 469/469 [==============================] - 18s 32ms/step - loss: 0.2460 - accuracy: 0.9268 - val_loss: 0.1015 - val_accuracy: 0.9695
# Epoch 2/20
# 469/469 [==============================] - 10s 21ms/step - loss: 0.1002 - accuracy: 0.9691 - val_loss: 0.0692 - val_accuracy: 0.9781
# Epoch 3/20
# 469/469 [==============================] - 9s 19ms/step - loss: 0.0724 - accuracy: 0.9771 - val_loss: 0.0680 - val_accuracy: 0.9787
# Epoch 4/20
# 469/469 [==============================] - 10s 22ms/step - loss: 0.0553 - accuracy: 0.9822 - val_loss: 0.0668 - val_accuracy: 0.9792
# Epoch 5/20
# 469/469 [==============================] - 11s 23ms/step - loss: 0.0466 - accuracy: 0.9852 - val_loss: 0.0684 - val_accuracy: 0.9789
# Epoch 6/20
# 469/469 [==============================] - 9s 19ms/step - loss: 0.0402 - accuracy: 0.9865 - val_loss: 0.0725 - val_accuracy: 0.9803
# Epoch 7/20
# 469/469 [==============================] - 10s 22ms/step - loss: 0.0325 - accuracy: 0.9894 - val_loss: 0.0571 - val_accuracy: 0.9842
# Epoch 8/20
# 469/469 [==============================] - 10s 21ms/step - loss: 0.0312 - accuracy: 0.9897 - val_loss: 0.0649 - val_accuracy: 0.9812
# Epoch 9/20
# 469/469 [==============================] - 9s 18ms/step - loss: 0.0264 - accuracy: 0.9914 - val_loss: 0.0572 - val_accuracy: 0.9842
# Epoch 10/20
# 469/469 [==============================] - 11s 23ms/step - loss: 0.0260 - accuracy: 0.9913 - val_loss: 0.0638 - val_accuracy: 0.9833
# Epoch 11/20
# 469/469 [==============================] - 11s 23ms/step - loss: 0.0231 - accuracy: 0.9926 - val_loss: 0.0690 - val_accuracy: 0.9831
# Epoch 12/20
# 469/469 [==============================] - 11s 24ms/step - loss: 0.0221 - accuracy: 0.9929 - val_loss: 0.0689 - val_accuracy: 0.9825
# Epoch 13/20
# 469/469 [==============================] - 11s 23ms/step - loss: 0.0192 - accuracy: 0.9934 - val_loss: 0.0658 - val_accuracy: 0.9846
# Epoch 14/20
# 469/469 [==============================] - 10s 22ms/step - loss: 0.0192 - accuracy: 0.9938 - val_loss: 0.0726 - val_accuracy: 0.9845
# Epoch 15/20
# 469/469 [==============================] - 10s 22ms/step - loss: 0.0187 - accuracy: 0.9937 - val_loss: 0.0708 - val_accuracy: 0.9848
# Epoch 16/20
# 469/469 [==============================] - 10s 22ms/step - loss: 0.0176 - accuracy: 0.9944 - val_loss: 0.0684 - val_accuracy: 0.9846
# Epoch 17/20
# 469/469 [==============================] - 10s 20ms/step - loss: 0.0173 - accuracy: 0.9943 - val_loss: 0.0741 - val_accuracy: 0.9830
# Epoch 18/20
# 469/469 [==============================] - 10s 22ms/step - loss: 0.0157 - accuracy: 0.9949 - val_loss: 0.0767 - val_accuracy: 0.9835
# Epoch 19/20
# 469/469 [==============================] - 10s 21ms/step - loss: 0.0168 - accuracy: 0.9943 - val_loss: 0.0769 - val_accuracy: 0.9848
# Epoch 20/20
# 469/469 [==============================] - 9s 19ms/step - loss: 0.0152 - accuracy: 0.9948 - val_loss: 0.0752 - val_accuracy: 0.9840

# %%
#  Plot one of the images in the test data, and then do inferencing to check what is the prediction of the model on that single image.
import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout
import matplotlib.pyplot as plt
import numpy as np

# loading mnist dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# normalize pixel values to range [0, 1]
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

# converting class labels to binary class matrices
num_classes = 10
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# to create a simple neural network model
model = Sequential()
model.add(Dense(512, activation='relu', input_shape=(784,)))
model.add(Dropout(0.2))
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation='softmax'))

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# to train the model
model.fit(x_train.reshape(-1, 784), y_train, validation_data=(x_test.reshape(-1, 784), y_test),
          epochs=20, batch_size=128)

# to plot one of the images in the test data
plt.imshow(x_test[0], cmap='gray')
plt.show()

# making a prediction on the image using the trained model
prediction = model.predict(x_test[0].reshape(1, -1))
print('Model prediction:', np.argmax(prediction))
# Out:
# Epoch 1/20
# 469/469 [==============================] - 13s 26ms/step - loss: 0.2502 - accuracy: 0.9252 - val_loss: 0.1026 - val_accuracy: 0.9684
# Epoch 2/20
# 469/469 [==============================] - 9s 19ms/step - loss: 0.1011 - accuracy: 0.9688 - val_loss: 0.0799 - val_accuracy: 0.9742
# Epoch 3/20
# 469/469 [==============================] - 10s 21ms/step - loss: 0.0707 - accuracy: 0.9782 - val_loss: 0.0673 - val_accuracy: 0.9789
# Epoch 4/20
# 469/469 [==============================] - 10s 22ms/step - loss: 0.0558 - accuracy: 0.9822 - val_loss: 0.0617 - val_accuracy: 0.9813
# Epoch 5/20
# 469/469 [==============================] - 9s 20ms/step - loss: 0.0470 - accuracy: 0.9849 - val_loss: 0.0632 - val_accuracy: 0.9800
# Epoch 6/20
# 469/469 [==============================] - 9s 20ms/step - loss: 0.0377 - accuracy: 0.9879 - val_loss: 0.0713 - val_accuracy: 0.9802
# Epoch 7/20
# 469/469 [==============================] - 10s 22ms/step - loss: 0.0345 - accuracy: 0.9883 - val_loss: 0.0737 - val_accuracy: 0.9779
# Epoch 8/20
# 469/469 [==============================] - 10s 21ms/step - loss: 0.0309 - accuracy: 0.9893 - val_loss: 0.0740 - val_accuracy: 0.9795
# Epoch 9/20
# 469/469 [==============================] - 9s 19ms/step - loss: 0.0259 - accuracy: 0.9912 - val_loss: 0.0642 - val_accuracy: 0.9830
# Epoch 10/20
# 469/469 [==============================] - 10s 22ms/step - loss: 0.0245 - accuracy: 0.9920 - val_loss: 0.0688 - val_accuracy: 0.9828
# Epoch 11/20
# 469/469 [==============================] - 11s 23ms/step - loss: 0.0222 - accuracy: 0.9922 - val_loss: 0.0844 - val_accuracy: 0.9806
# Epoch 12/20
# 469/469 [==============================] - 9s 19ms/step - loss: 0.0221 - accuracy: 0.9929 - val_loss: 0.0759 - val_accuracy: 0.9813
# Epoch 13/20
# 469/469 [==============================] - 10s 22ms/step - loss: 0.0223 - accuracy: 0.9924 - val_loss: 0.0737 - val_accuracy: 0.9817
# Epoch 14/20
# 469/469 [==============================] - 10s 22ms/step - loss: 0.0197 - accuracy: 0.9937 - val_loss: 0.0807 - val_accuracy: 0.9816
# Epoch 15/20
# 469/469 [==============================] - 9s 19ms/step - loss: 0.0194 - accuracy: 0.9936 - val_loss: 0.0778 - val_accuracy: 0.9821
# Epoch 16/20
# 469/469 [==============================] - 13s 27ms/step - loss: 0.0183 - accuracy: 0.9942 - val_loss: 0.0758 - val_accuracy: 0.9820
# Epoch 17/20
# 469/469 [==============================] - 10s 22ms/step - loss: 0.0150 - accuracy: 0.9948 - val_loss: 0.0735 - val_accuracy: 0.9822
# Epoch 18/20
# 469/469 [==============================] - 10s 22ms/step - loss: 0.0146 - accuracy: 0.9952 - val_loss: 0.0804 - val_accuracy: 0.9819
# Epoch 19/20
# 469/469 [==============================] - 9s 18ms/step - loss: 0.0153 - accuracy: 0.9952 - val_loss: 0.0811 - val_accuracy: 0.9827
# Epoch 20/20
# 469/469 [==============================] - 10s 22ms/step - loss: 0.0165 - accuracy: 0.9942 - val_loss: 0.0798 - val_accuracy: 0.9823
# 1/1 [==============================] - 0s 104ms/step
# Model prediction: 7

# %%
# We had used 2 hidden layers and Relu activation. Try to change the number of hidden layer and the activation to tanh or sigmoid and see what happens.
import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout
import matplotlib.pyplot as plt
import numpy as np

# load MNIST dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# normalize pixel values to range [0, 1]
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

# convert class labels to binary class matrices
num_classes = 10
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# create a list of models to train
models = []

# model with 1 hidden layer and tanh activation
model = Sequential()
model.add(Dense(512, activation='tanh', input_shape=(784,)))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation='softmax'))
models.append(('1 hidden layer with tanh', model))

# model with 1 hidden layer and sigmoid activation
model = Sequential()
model.add(Dense(512, activation='sigmoid', input_shape=(784,)))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation='softmax'))
models.append(('1 hidden layer with sigmoid', model))

# model with 2 hidden layers and tanh activation
model = Sequential()
model.add(Dense(512, activation='tanh', input_shape=(784,)))
model.add(Dropout(0.2))
model.add(Dense(512, activation='tanh'))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation='softmax'))
models.append(('2 hidden layers with tanh', model))

# model with 2 hidden layers and sigmoid activation
model = Sequential()
model.add(Dense(512, activation='sigmoid', input_shape=(784,)))
model.add(Dropout(0.2))
model.add(Dense(512, activation='sigmoid'))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation='softmax'))
models.append(('2 hidden layers with sigmoid', model))

# train each model and plot loss and accuracy curves
for name, model in models:
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    history = model.fit(x_train.reshape(-1, 784), y_train, validation_data=(x_test.reshape(-1, 784), y_test),epochs=20, batch_size=128, verbose=0)
    # plot loss and accuracy curves
    plt.plot(history.history['loss'], label='train_loss')
    plt.plot(history.history['val_loss'], label='val_loss')
    plt.plot(history.history['accuracy'], label='train_accuracy')
    plt.plot(history.history['val_accuracy'], label='val_accuracy')
    plt.title(name)
    plt.xlabel('Epoch')
    plt.legend()
    plt.show()

    # evaluate the model on test data
    loss, accuracy = model.evaluate(x_test.reshape(-1, 784), y_test, verbose=0)
    print('{} - Test loss: {:.4f}, Test accuracy: {:.4f}'.format(name, loss, accuracy))
# Out:
# 1 hidden layer with tanh - Test loss: 0.0706, Test accuracy: 0.9798
# 1 hidden layer with sigmoid - Test loss: 0.0610, Test accuracy: 0.9816
# 2 hidden layers with tanh - Test loss: 0.0745, Test accuracy: 0.9796
# 2 hidden layers with sigmoid - Test loss: 0.0667, Test accuracy: 0.9817

# %%
# Run the same code without scaling the images and check the performance
import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout
import matplotlib.pyplot as plt
import numpy as np

# load mnist dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# convert class labels to binary class matrices
num_classes = 10
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# create a list of models to train
models = []

# model with 1 hidden layer and tanh activation
model = Sequential()
model.add(Dense(512, activation='tanh', input_shape=(784,)))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation='softmax'))
models.append(('1 hidden layer with tanh', model))

# model with 1 hidden layer and sigmoid activation
model = Sequential()
model.add(Dense(512, activation='sigmoid', input_shape=(784,)))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation='softmax'))
models.append(('1 hidden layer with sigmoid', model))

# model with 2 hidden layers and tanh activation
model = Sequential()
model.add(Dense(512, activation='tanh', input_shape=(784,)))
model.add(Dropout(0.2))
model.add(Dense(512, activation='tanh'))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation='softmax'))
models.append(('2 hidden layers with tanh', model))

# model with 2 hidden layers and sigmoid activation
model = Sequential()
model.add(Dense(512, activation='sigmoid', input_shape=(784,)))
model.add(Dropout(0.2))
model.add(Dense(512, activation='sigmoid'))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation='softmax'))
models.append(('2 hidden layers with sigmoid', model))

# train each model and plot loss and accuracy curves
for name, model in models:
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    history = model.fit(x_train.reshape(-1, 784), y_train, validation_data=(x_test.reshape(-1, 784), y_test),
                        epochs=20, batch_size=128, verbose=0)
    # plot loss and accuracy curves
    plt.plot(history.history['loss'], label='train_loss')
    plt.plot(history.history['val_loss'], label='val_loss')
    plt.plot(history.history['accuracy'], label='train_accuracy')
    plt.plot(history.history['val_accuracy'], label='val_accuracy')
    plt.title(name)
    plt.xlabel('Epoch')
    plt.legend()
    plt.show()

    # evaluate the model on test data
    loss, accuracy = model.evaluate(x_test.reshape(-1, 784), y_test, verbose=0)
    print('{} - Test loss: {:.4f}, Test accuracy: {:.4f}'.format(name, loss, accuracy))
# Out:
# 1 hidden layer with tanh - Test loss: 0.1750, Test accuracy: 0.9474
# 1 hidden layer with sigmoid - Test loss: 0.1408, Test accuracy: 0.9573
# 2 hidden layers with tanh - Test loss: 0.1367, Test accuracy: 0.9561
# 2 hidden layers with sigmoid - Test loss: 0.1070, Test accuracy: 0.9671
